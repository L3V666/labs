# %% [markdown]
# 1. Пузырек, но быстрее

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

plt.xlabel('n')
plt.ylabel('t')
# Out:
# Text(0, 0.5, 't')

# %%
data_0 = np.array(pd.read_csv('-O0.csv', header=None))

plt.plot(data_0[:, 0], data_0[:, 1], label='-O0')

data_1 = np.array(pd.read_csv('-O3.csv', header=None))

plt.plot(data_1[:, 0], data_1[:, 1], label='-O2')

data_2 = np.array(pd.read_csv('-O2.csv', header=None))

plt.plot(data_2[:, 0], data_2[:, 1], label='-O1')

data_3 = np.array(pd.read_csv('-O1.csv', header=None))

plt.plot(data_3[:, 0], data_3[:, 1], label='-O3')





plt.grid()

plt.legend()
